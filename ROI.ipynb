# %%
import cv2
import numpy as np

# Load the image
image_path = r"C:\Users\Sambhavi Roy\OneDrive\Pictures\Screenshots\Screenshot 2025-02-24 171216.png"  # Update this if needed
output_path = r"C:\Users\Sambhavi Roy\Downloads\road_aoi_marked.png"  # Save path
image = cv2.imread(image_path)

# Get image dimensions
frame_height, frame_width = image.shape[:2]

# Define road polygon points (manually set based on the road region)
road_polygon = np.array([[50, 200], [150, 150], [1500, 960], [1092, 1052]], np.int32)

# Create a blank mask
mask = np.zeros((frame_height, frame_width), dtype=np.uint8)

# Fill the mask with the polygon (road area)
cv2.fillPoly(mask, [road_polygon], 255)

# Draw the polygon on the image for debugging
cv2.polylines(image, [road_polygon], isClosed=True, color=(0, 255, 0), thickness=3)  # Green boundary

# Save the output image
cv2.imwrite(output_path, image)
print(f"Output image saved at: {output_path}")
# Out:
# Output image saved at: C:\Users\Sambhavi Roy\Downloads\road_aoi_marked.png

# %% [markdown]
# Sample 2

# %%
import cv2
import numpy as np

# Load the image
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 2\Screenshot 2025-03-26 230315.png"  # Update this if needed
output_path = r"C:\Users\Sambhavi Roy\Downloads\sample 2\sample2road_aoi_marked.png"  # Save path
image = cv2.imread(image_path)

# Get image dimensions
frame_height, frame_width = image.shape[:2]

# Define road polygon points (manually set based on the road region)
road_polygon = np.array([[100, 350], [100, 300], [1099, 910], [1000, 1000]], np.int32)

# Create a blank mask
mask = np.zeros((frame_height, frame_width), dtype=np.uint8)

# Fill the mask with the polygon (road area)
cv2.fillPoly(mask, [road_polygon], 255)

# Draw the polygon on the image for debugging
cv2.polylines(image, [road_polygon], isClosed=True, color=(0, 255, 0), thickness=3)  # Green boundary

# Save the output image
cv2.imwrite(output_path, image)
print(f"Output image saved at: {output_path}")
# Out:
# Output image saved at: C:\Users\Sambhavi Roy\Downloads\sample 2\sample2road_aoi_marked.png

# %% [markdown]
# cycle 3

# %%
import cv2
import numpy as np

# Load the image
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 3\Screenshot 2025-04-07 182113.png"  # Update this if needed
output_path = r"C:\Users\Sambhavi Roy\Downloads\sample 3\sample3road_aoi_marked.png"  # Save path
image = cv2.imread(image_path)

# Get image dimensions
frame_height, frame_width = image.shape[:2]

# Define road polygon points (manually set based on the road region)
road_polygon = np.array([[20, 30], [10, 100], [1200, 1000], [1400, 900]], np.int32)

# Create a blank mask
mask = np.zeros((frame_height, frame_width), dtype=np.uint8)

# Fill the mask with the polygon (road area)
cv2.fillPoly(mask, [road_polygon], 255)

# Draw the polygon on the image for debugging
cv2.polylines(image, [road_polygon], isClosed=True, color=(0, 255, 0), thickness=3)  # Green boundary

# Save the output image
cv2.imwrite(output_path, image)
print(f"Output image saved at: {output_path}")
# Out:
# Output image saved at: C:\Users\Sambhavi Roy\Downloads\sample 3\sample3road_aoi_marked.png

# %% [markdown]
# 4cycle

# %%
import cv2
import numpy as np

# Load the image
image_path = r"C:\Users\Sambhavi Roy\Downloads\4cycle\Screenshot 2025-04-17 154558.png"  # Update this if needed
output_path = r"C:\Users\Sambhavi Roy\Downloads\4cycle\road_aoi_marked.png"  # Save path
image = cv2.imread(image_path)

# Get image dimensions
frame_height, frame_width = image.shape[:2]

# Define road polygon points (manually set based on the road region)
road_polygon = np.array([[100, 300], [10, 300], [975, 1075], [1300, 1000]], np.int32)

# Create a blank mask
mask = np.zeros((frame_height, frame_width), dtype=np.uint8)

# Fill the mask with the polygon (road area)
cv2.fillPoly(mask, [road_polygon], 255)

# Draw the polygon on the image for debugging
cv2.polylines(image, [road_polygon], isClosed=True, color=(0, 255, 0), thickness=3)  # Green boundary

# Save the output image
cv2.imwrite(output_path, image)
print(f"Output image saved at: {output_path}")
# Out:
# Output image saved at: C:\Users\Sambhavi Roy\Downloads\4cycle\road_aoi_marked.png

# %% [markdown]
# part 2

# %%
import cv2
import numpy as np

# Load the image
image_path = r"C:\Users\Sambhavi Roy\Downloads\4cycle\part 2.png"  # Update this if needed
output_path = r"C:\Users\Sambhavi Roy\Downloads\4cycle\part2marked.png"  # Save path
image = cv2.imread(image_path)

# Get image dimensions
frame_height, frame_width = image.shape[:2]

# Define road polygon points (manually set based on the road region)
road_polygon = np.array([[12, 216], [98, 172], [1312, 932], [1084, 1056]], np.int32)

# Create a blank mask
mask = np.zeros((frame_height, frame_width), dtype=np.uint8)

# Fill the mask with the polygon (road area)
cv2.fillPoly(mask, [road_polygon], 255)

# Draw the polygon on the image for debugging
cv2.polylines(image, [road_polygon], isClosed=True, color=(0, 255, 0), thickness=3)  # Green boundary

# Save the output image
cv2.imwrite(output_path, image)
print(f"Output image saved at: {output_path}")
# Out:
# Output image saved at: C:\Users\Sambhavi Roy\Downloads\4cycle\part2marked.png

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\4cycle\part 2.png"  # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [12, 216],
#     [98, 172],
#     [1312, 932],
#     [1084, 1056],
#     [16, 220],
# ], np.int32)

# %% [markdown]
# sample 4

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 4\Screenshot 2025-04-18 121028.png" # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [56, 162],
#     [144, 124],
#     [1498, 898],
#     [1234, 1060],
#     [56, 164],
# ], np.int32)

# %% [markdown]
# sample 5

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 5\Screenshot 2025-04-18 152902.png" # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [52, 178],
#     [162, 158],
#     [1480, 922],
#     [1202, 1064],
#     [52, 184],
# ], np.int32)

# %% [markdown]
# sample 6

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 6\Screenshot 2025-04-21 165554.png" # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [118, 146],
#     [188, 115],
#     [1434, 908],
#     [1266, 1064],
#     [122, 142],
# ], np.int32)

# %% [markdown]
# sample 7

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 7\Screenshot 2025-04-21 172230.png" # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [94, 100],
#     [176, 74],
#     [1430, 882],
#     [1198, 994],
#     [98, 100],
# ], np.int32)

# %% [markdown]
# sample 8

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 8\Screenshot 2025-04-21 180036.png" # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [208, 178],
#     [286, 146],
#     [1486, 926],
#     [1290, 1062],
#     [212, 178],
# ], np.int32)

# %% [markdown]
# sample 9

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 9\Screenshot 2025-04-21 185030.png" # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [200, 206],
#     [274, 168],
#     [1512, 972],
#     [1254, 1060],
#     [208, 204],
# ], np.int32)

# %% [markdown]
# sample 10

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 10\Screenshot 2025-04-21 224024.png" # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [294, 272],
#     [390, 246],
#     [1432, 930],
#     [1246, 1060],
#     [296, 272],
# ], np.int32)

# %% [markdown]
# sample 11

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 11\Screenshot 2025-04-28 120846.png" # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [34, 252],
#     [222, 186],
#     [1718, 746],
#     [1414, 1002],
#     [38, 252],
# ], np.int32)

# %% [markdown]
# sample 12

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 12\Screenshot 2025-04-28 125237.png" # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [22, 162],
#     [174, 90],
#     [1884, 736],
#     [1498, 1010],
#     [26, 164],
# ], np.int32)

# %% [markdown]
# sample 13

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 13\Screenshot 2025-04-28 165648.png" # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [16, 252],
#     [196, 172],
#     [1736, 786],
#     [1416, 1026],
#     [18, 250],
# ], np.int32)

# %% [markdown]
# sample 14

# %%
import cv2
import numpy as np

# Path to your screenshot
image_path = r"C:\Users\Sambhavi Roy\Downloads\sample 14\Screenshot 2025-04-28 172435.png" # <-- Change to your screenshot name

# Load original image
original = cv2.imread(image_path)
if original is None:
    raise FileNotFoundError(f"Could not load image at {image_path}")

# Resize for display only
scale_percent = 50  # Display at 50% size (change if needed)
width = int(original.shape[1] * scale_percent / 100)
height = int(original.shape[0] * scale_percent / 100)
resized = cv2.resize(original, (width, height))

clone = resized.copy()
roi_points_display = []
roi_points_original = []

def draw_polygon(event, x, y, flags, param):
    global roi_points_display, roi_points_original, resized, original

    if event == cv2.EVENT_LBUTTONDOWN:
        roi_points_display.append((x, y))
        # Map display point to original coordinates
        orig_x = int(x / scale_percent * 100)
        orig_y = int(y / scale_percent * 100)
        roi_points_original.append((orig_x, orig_y))

        cv2.circle(resized, (x, y), 4, (0, 255, 0), -1)
        if len(roi_points_display) > 1:
            cv2.line(resized, roi_points_display[-2], roi_points_display[-1], (255, 0, 0), 2)
        cv2.imshow("Select ROI - ESC to finish", resized)

print("\n🖱️ Click to select ROI points (clockwise). Press ESC to finish.\n")

cv2.imshow("Select ROI - ESC to finish", resized)
cv2.setMouseCallback("Select ROI - ESC to finish", draw_polygon)

while True:
    key = cv2.waitKey(1) & 0xFF
    if key == 27:  # ESC
        if len(roi_points_display) > 2:
            cv2.line(resized, roi_points_display[-1], roi_points_display[0], (255, 0, 0), 2)
        break

cv2.destroyAllWindows()

# Output original coordinates
print("\n📍 Your ROI polygon coordinates (original scale):")
print("road_polygon_ref = np.array([")
for point in roi_points_original:
    print(f"    [{point[0]}, {point[1]}],")
print("], np.int32)")
# Out:
# 🖱️ Click to select ROI points (clockwise). Press ESC to finish.
#
#
# 📍 Your ROI polygon coordinates (original scale):
# road_polygon_ref = np.array([
#     [16, 222],
#     [248, 140],
#     [1852, 722],
#     [1376, 969],
#     [20, 224],
# ], np.int32)
